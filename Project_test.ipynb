# %% [markdown]
# <a href="https://colab.research.google.com/github/AsimMarey/Project-data/blob/main/Project_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O plantnet300K.zip https://zenodo.org/records/5645731/files/plantnet_300K.zip
# Out:
# --2024-01-02 17:48:55--  https://zenodo.org/records/5645731/files/plantnet_300K.zip
# Resolving zenodo.org (zenodo.org)... 188.185.79.172, 188.184.103.159, 188.184.98.238, ...
# Connecting to zenodo.org (zenodo.org)|188.185.79.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31670505069 (29G) [application/octet-stream]
# Saving to: ‘plantnet300K.zip’
#
# plantnet300K.zip    100%[===================>]  29.50G  12.7MB/s    in 38m 49s
#
# 2024-01-02 18:27:45 (13.0 MB/s) - ‘plantnet300K.zip’ saved [31670505069/31670505069]

# %%
# !git config --global user.email "email"
# !git config --global user.name "name"

# %%
# %cd /content
# !mkdir projectdata
# %cd projectdata
# Out:
# /content
# /content/projectdata

# %%
from google.colab import files

# Use the Colab file upload widget
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fde96017-a6b1-490a-ab24-fe5d053321b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fde96017-a6b1-490a-ab24-fe5d053321b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip plantnet300K.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: plantnet_300K/images/val/1363764/1093b5145e6bf3d169b7afe85871489d0ab2466d.jpg
#   inflating: plantnet_300K/images/val/1363764/99e730d8fcd8c5c79638429dc025ce64ff07cfbb.jpg
#   inflating: plantnet_300K/images/val/1363764/ca35286c8c46e24aa9723d34fd73af7d8110c9ee.jpg
#   inflating: plantnet_300K/images/val/1363764/dc1e1c0506597e11e8265d7140c616592c5ad235.jpg
#   inflating: plantnet_300K/images/val/1363764/8c46f21bd109838c2f5033eda5523374ab7c8dd0.jpg
#   inflating: plantnet_300K/images/val/1363764/2fefc0da1d09d4bf46f0363fa142b11551b89c1d.jpg
#   inflating: plantnet_300K/images/val/1363764/471c68ef8a0b548516e63059dff3fbf3ca02b76d.jpg
#   inflating: plantnet_300K/images/val/1363764/a337ce3b3312a01e511f23a04990b655f7827955.jpg
#   inflating: plantnet_300K/images/val/1363764/5d3beb5d047f54aea9d6bcd24bc4e7f7c6f861a1.jpg
#   inflating: plantnet_300K/images/val/1363764/8fd53bf207b6f58ba902b4146f66260becc56027.jpg
# ...
